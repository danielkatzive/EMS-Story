# %%
import pandas as pd
from datetime import datetime
pd.options.display.float_format='{:,.0f}'.format
import numpy as np

# %%
df = pd.read_csv("EMS severe data.csv")
##importing EMS call data from March 31 2021 to March 31 2022, Level 1, 2, 3 severity only

# %%
df
# Out:
#         CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             220903991  03/31/2022 08:18:35 PM            INJMAJ
# 1             220903988  03/31/2022 08:17:52 PM            INJMAJ
# 2             220903983  03/31/2022 08:16:29 PM            INJMAJ
# 3             220903968  03/31/2022 08:12:49 PM            PEDSTR
# 4             220903960  03/31/2022 08:11:23 PM            PEDSTR
# ...                 ...                     ...               ...
# 540613        210903808  03/31/2021 08:22:00 PM            STATEP
# 540614        210903804  03/31/2021 08:22:00 PM               UNC
# 540615        210903800  03/31/2021 08:21:00 PM            DIFFBR
# 540616        210903799  03/31/2021 08:20:00 PM            CARDBR
# 540617        210903796  03/31/2021 08:20:00 PM            ALTMEN
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 3          INJMAJ
# 1                                 3          INJMAJ
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540618 entries, 0 to 540617
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 540618 non-null  int64
#  1   INCIDENT_DATETIME               540618 non-null  object
#  2   INITIAL_CALL_TYPE               540618 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     540618 non-null  int64
#  4   FINAL_CALL_TYPE                 540618 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       540618 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       539480 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  540618 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    540618 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       538871 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         528721 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  540618 non-null  object
# ...

# %%
df.describe()
# Out:
#        CAD_INCIDENT_ID  INITIAL_SEVERITY_LEVEL_CODE  \
# count          540,618                      540,618
# mean       214,243,040                            2
# std          3,556,294                            1
# min        210,903,796                            1
# 25%        211,814,003                            2
# 50%        212,711,732                            2
# 75%        213,623,627                            3
# max        220,903,991                            3
#
#        FINAL_SEVERITY_LEVEL_CODE  DISPATCH_RESPONSE_SECONDS_QY  \
# count                    540,618                       540,618
# mean                           3                            29
# std                            1                            86
# min                            1                             0
# 25%                            2                            11
# 50%                            2                            18
# ...

# %%
df["INCIDENT_RESPONSE_SECONDS_QY"].mean()
# Out:
# 424.40474281088524

# %%
zip_gb = df.groupby("ZIPCODE")

# %%
zip_gb.describe()
# Out:
#         CAD_INCIDENT_ID                                                \
#                   count        mean       std         min         25%
# ZIPCODE
# 10,000               47 213,883,527 3,269,391 210,932,284 211,956,648
# 10,001            5,652 214,099,703 3,483,692 210,904,290 211,793,012
# 10,002            6,753 214,137,639 3,510,831 210,903,804 211,792,093
# 10,003            4,150 214,309,953 3,561,877 210,904,238 211,903,195
# 10,004              627 214,116,748 3,544,569 210,904,220 211,757,712
# ...                 ...         ...       ...         ...         ...
# 11,693              794 213,968,042 3,396,821 210,911,208 211,844,551
# 11,694            1,330 214,339,471 3,614,652 210,911,050 211,852,446
# 11,695                9 212,295,098   629,849 211,133,256 212,031,736
# 11,697              152 213,851,421 3,318,585 210,932,635 211,961,407
# 12,345                1 211,993,889       NaN 211,993,889 211,993,889
#
# ...

# %%
mean_zip=zip_gb.mean()

# %%
mean_zip
# Out:
#          CAD_INCIDENT_ID  INITIAL_SEVERITY_LEVEL_CODE  \
# ZIPCODE
# 10,000       213,883,527                            3
# 10,001       214,099,703                            2
# 10,002       214,137,639                            2
# 10,003       214,309,953                            2
# 10,004       214,116,748                            2
# ...                  ...                          ...
# 11,693       213,968,042                            2
# 11,694       214,339,471                            2
# 11,695       212,295,098                            3
# 11,697       213,851,421                            2
# 12,345       211,993,889                            2
#
#          FINAL_SEVERITY_LEVEL_CODE  DISPATCH_RESPONSE_SECONDS_QY  \
# ZIPCODE
# 10,000                           2                            53
# 10,001                           2                            29
# 10,002                           2                            23
# ...

# %%
mean_zip.to_csv("ems data severe by zip2", index = True, encoding = "UTF8")

# %%
df["INCIDENT_DATETIME"]=pd.to_datetime(df["INCIDENT_DATETIME"])

# %%
df["FIRST_ON_SCENE_DATETIME"]=pd.to_datetime(df["FIRST_ON_SCENE_DATETIME"])

# %%
df["FIRST_TO_HOSP_DATETIME"]=pd.to_datetime(df["FIRST_TO_HOSP_DATETIME"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540618 entries, 0 to 540617
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 540618 non-null  int64
#  1   INCIDENT_DATETIME               540618 non-null  datetime64[ns]
#  2   INITIAL_CALL_TYPE               540618 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     540618 non-null  int64
#  4   FINAL_CALL_TYPE                 540618 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       540618 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       539480 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  540618 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    540618 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       538871 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         528721 non-null  datetime64[ns]
# ...

# %%
df["FIRST_HOSP_ARRIVAL_DATETIME"]=pd.to_datetime(df["FIRST_HOSP_ARRIVAL_DATETIME"])

# %%
df["HOSPITAL_TRAVEL"]=df["FIRST_HOSP_ARRIVAL_DATETIME"]-df["FIRST_TO_HOSP_DATETIME"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540618 entries, 0 to 540617
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 540618 non-null  int64
#  1   INCIDENT_DATETIME               540618 non-null  datetime64[ns]
#  2   INITIAL_CALL_TYPE               540618 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     540618 non-null  int64
#  4   FINAL_CALL_TYPE                 540618 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       540618 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       539480 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  540618 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    540618 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       538871 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         528721 non-null  datetime64[ns]
# ...

# %%
df["HOSPITAL_TRAVEL"]=df["HOSPITAL_TRAVEL"].dt.total_seconds()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540618 entries, 0 to 540617
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 540618 non-null  int64
#  1   INCIDENT_DATETIME               540618 non-null  datetime64[ns]
#  2   INITIAL_CALL_TYPE               540618 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     540618 non-null  int64
#  4   FINAL_CALL_TYPE                 540618 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       540618 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       539480 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  540618 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    540618 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       538871 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         528721 non-null  datetime64[ns]
# ...

# %%
df.head(20)
# Out:
#     CAD_INCIDENT_ID   INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0         220903991 2022-03-31 20:18:35            INJMAJ
# 1         220903988 2022-03-31 20:17:52            INJMAJ
# 2         220903983 2022-03-31 20:16:29            INJMAJ
# 3         220903968 2022-03-31 20:12:49            PEDSTR
# 4         220903960 2022-03-31 20:11:23            PEDSTR
# 5         220903954 2022-03-31 20:10:37            STATEP
# 6         220903948 2022-03-31 20:09:09            STATEP
# 7         220903945 2022-03-31 20:08:27            CARDBR
# 8         220903941 2022-03-31 20:08:09             MCI21
# 9         220903933 2022-03-31 20:06:01            STATEP
# 10        220903930 2022-03-31 20:04:36               UNC
# 11        220903928 2022-03-31 20:03:45              CARD
# 12        220903926 2022-03-31 20:03:33               UNC
# 13        220903925 2022-03-31 20:03:29            CARDBR
# 14        220903923 2022-03-31 20:02:56            BURNMA
# ...

# %%
df["HOSPITAL_TRAVEL"].mean()
# Out:
# 698.6879420734141

# %%
df.describe()
# Out:
#        CAD_INCIDENT_ID  INITIAL_SEVERITY_LEVEL_CODE  \
# count          540,618                      540,618
# mean       214,243,040                            2
# std          3,556,294                            1
# min        210,903,796                            1
# 25%        211,814,003                            2
# 50%        212,711,732                            2
# 75%        213,623,627                            3
# max        220,903,991                            3
#
#        FINAL_SEVERITY_LEVEL_CODE  DISPATCH_RESPONSE_SECONDS_QY  \
# count                    540,618                       540,618
# mean                           3                            29
# std                            1                            86
# min                            1                             0
# 25%                            2                            11
# 50%                            2                            18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540618 entries, 0 to 540617
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 540618 non-null  int64
#  1   INCIDENT_DATETIME               540618 non-null  datetime64[ns]
#  2   INITIAL_CALL_TYPE               540618 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     540618 non-null  int64
#  4   FINAL_CALL_TYPE                 540618 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       540618 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       539480 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  540618 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    540618 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       538871 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         528721 non-null  datetime64[ns]
# ...

# %%
zip_gb_mean = df.groupby("ZIPCODE").mean()

# %%
zip_gb_mean.sort_values(by="INCIDENT_RESPONSE_SECONDS_QY", ascending=0)
# Out:
#          CAD_INCIDENT_ID  INITIAL_SEVERITY_LEVEL_CODE  \
# ZIPCODE
# 11,697       213,851,421                            2
# 11,695       212,295,098                            3
# 10,158       216,627,434                            2
# 11,430       214,532,623                            2
# 10,000       213,883,527                            3
# ...                  ...                          ...
# 10,115       211,452,357                            2
# 10,048       213,502,862                            3
# 10,279       212,475,317                            3
# 10,152       212,174,526                            2
# 11,242       220,473,104                            3
#
#          FINAL_SEVERITY_LEVEL_CODE  DISPATCH_RESPONSE_SECONDS_QY  \
# ZIPCODE
# 11,697                           3                            47
# 11,695                           3                            20
# 10,158                           2                            26
# ...

# %%
zip_gb_mean.to_csv("ems severe by zip3", index = True, encoding = "UTF8")

# %%
zip_gb_mean.describe()
# Out:
#        CAD_INCIDENT_ID  INITIAL_SEVERITY_LEVEL_CODE  \
# count              230                          230
# mean       214,153,012                            2
# std            810,315                            0
# min        211,452,357                            2
# 25%        214,090,037                            2
# 50%        214,223,934                            2
# 75%        214,331,108                            2
# max        220,473,104                            3
#
#        FINAL_SEVERITY_LEVEL_CODE  DISPATCH_RESPONSE_SECONDS_QY  \
# count                        230                           230
# mean                           3                            27
# std                            0                             6
# min                            2                             6
# 25%                            2                            24
# 50%                            3                            27
# ...

# %%
df_sub=df[["INCIDENT_DATETIME", "INCIDENT_RESPONSE_SECONDS_QY","FIRST_TO_HOSP_DATETIME",\
           "FIRST_HOSP_ARRIVAL_DATETIME", "HELD_INDICATOR","HOSPITAL_TRAVEL", "ZIPCODE", "INCIDENT_DISPOSITION_CODE" ]]

# %%
df_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540618 entries, 0 to 540617
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   INCIDENT_DATETIME             540618 non-null  datetime64[ns]
#  1   INCIDENT_RESPONSE_SECONDS_QY  528716 non-null  float64
#  2   FIRST_TO_HOSP_DATETIME        377596 non-null  datetime64[ns]
#  3   FIRST_HOSP_ARRIVAL_DATETIME   375786 non-null  datetime64[ns]
#  4   HELD_INDICATOR                540618 non-null  object
#  5   HOSPITAL_TRAVEL               375786 non-null  float64
#  6   ZIPCODE                       534141 non-null  float64
#  7   INCIDENT_DISPOSITION_CODE     539340 non-null  float64
# dtypes: datetime64[ns](3), float64(4), object(1)
# memory usage: 33.0+ MB

# %%
df_sub.describe()
# Out:
#        INCIDENT_RESPONSE_SECONDS_QY  HOSPITAL_TRAVEL  ZIPCODE  \
# count                       528,716          375,786  534,141
# mean                            424              699   10,740
# std                             229              426      546
# min                               0                0   10,000
# 25%                             284              404   10,303
# 50%                             389              614   10,472
# 75%                             521              900   11,226
# max                          14,539            7,418   12,345
#
#        INCIDENT_DISPOSITION_CODE
# count                    539,340
# mean                          85
# std                            5
# min                           82
# 25%                           82
# 50%                           82
# 75%                           90
# max                           96

# %%
df_sub
# Out:
#          INCIDENT_DATETIME  INCIDENT_RESPONSE_SECONDS_QY  \
# 0      2022-03-31 20:18:35                           314
# 1      2022-03-31 20:17:52                           402
# 2      2022-03-31 20:16:29                           172
# 3      2022-03-31 20:12:49                           NaN
# 4      2022-03-31 20:11:23                           392
# ...                    ...                           ...
# 540613 2021-03-31 20:22:00                           552
# 540614 2021-03-31 20:22:00                           462
# 540615 2021-03-31 20:21:00                           403
# 540616 2021-03-31 20:20:00                           516
# 540617 2021-03-31 20:20:00                           505
#
#        FIRST_TO_HOSP_DATETIME FIRST_HOSP_ARRIVAL_DATETIME HELD_INDICATOR  \
# 0         2022-03-31 20:46:18         2022-03-31 20:58:24              N
# 1         2022-03-31 21:23:45         2022-03-31 21:36:58              N
# ...

# %%
df_breezy=df_sub.query("ZIPCODE==11697")

# %%
df_breezy.sort_values(by="HOSPITAL_TRAVEL", ascending=0)
# Out:
#          INCIDENT_DATETIME  INCIDENT_RESPONSE_SECONDS_QY  \
# 533885 2021-04-05 15:33:00                         1,217
# 496393 2021-05-01 10:04:00                           562
# 124909 2022-01-03 21:22:39                         1,151
# 78026  2022-02-04 10:26:55                           883
# 471412 2021-05-18 10:58:05                           968
# ...                    ...                           ...
# 527666 2021-04-09 17:40:00                           817
# 532958 2021-04-06 08:53:00                           526
# 533889 2021-04-05 15:30:00                           864
# 535490 2021-04-04 14:10:00                           NaN
# 536731 2021-04-03 16:22:00                         1,046
#
#        FIRST_TO_HOSP_DATETIME FIRST_HOSP_ARRIVAL_DATETIME HELD_INDICATOR  \
# 533885    2021-04-05 16:45:00         2021-04-05 17:43:00              N
# 496393    2021-05-01 11:14:00         2021-05-01 12:05:00              N
# ...

# %%
df_ERS = pd.read_excel("NYC ER ZIPS.xlsx")

# %%
df_sub.dtypes
# Out:
# INCIDENT_DATETIME               datetime64[ns]
# INCIDENT_RESPONSE_SECONDS_QY           float64
# FIRST_TO_HOSP_DATETIME          datetime64[ns]
# FIRST_HOSP_ARRIVAL_DATETIME     datetime64[ns]
# HELD_INDICATOR                          object
# HOSPITAL_TRAVEL                        float64
# ZIPCODE                                float64
# INCIDENT_DISPOSITION_CODE              float64
# dtype: object

# %%
df_ERS.info()
df_ERS.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ZIPCODE  50 non-null     int64
#  1   ER       50 non-null     bool
# dtypes: bool(1), int64(1)
# memory usage: 578.0 bytes
# ZIPCODE    int64
# ER          bool
# dtype: object

# %%
df_ERS.head(50)
# Out:
#     ZIPCODE    ER
# 0     10016  True
# 1     10456  True
# 2     11212  True
# 3     11201  True
# 4     11373  True
# 5     11355  True
# 6     10037  True
# 7     11213  True
# 8     10461  True
# 9     11418  True
# 10    11203  True
# 11    11203  True
# 12    10011  True
# 13    10021  True
# 14    10451  True
# 15    11375  True
# 16    11040  True
# 17    11219  True
# 18    11229  True
# 19    10029  True
# 20    10461  True
# 21    10467  True
# 22    10461  True
# 23    10466  True
# 24    10003  True
# 25    11234  True
# 26    10029  True
# 27    11102  True
# 28    10025  True
# 29    10019  True
# 30    11215  True
# 31    10034  True
# 32    10032  True
# 33    10021  True
# 34    10038  True
# 35    11355  True
# 36    10467  True
# 37    11235  True
# 38    11201  True
# 39    11220  True
# 40    10016  True
# 41    11432  True
# 42    10310  True
# 43    10457  True
# 44    11691  True
# 45    10305  True
# 46    10309  True
# 47    11203  True
# 48    11206  True
# ...

# %%
#df_ER_info=pd.merge(df_sub,df_ERS)

df_ER_info = df_ERS.merge(df_sub, on = "ZIPCODE", how ="right")

# %%
df_ER_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 589966 entries, 0 to 589965
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ZIPCODE                       583489 non-null  float64
#  1   ER                            215058 non-null  object
#  2   INCIDENT_DATETIME             589966 non-null  datetime64[ns]
#  3   INCIDENT_RESPONSE_SECONDS_QY  576966 non-null  float64
#  4   FIRST_TO_HOSP_DATETIME        413308 non-null  datetime64[ns]
#  5   FIRST_HOSP_ARRIVAL_DATETIME   411321 non-null  datetime64[ns]
#  6   HELD_INDICATOR                589966 non-null  object
#  7   HOSPITAL_TRAVEL               411321 non-null  float64
#  8   INCIDENT_DISPOSITION_CODE     588590 non-null  float64
# dtypes: datetime64[ns](3), float64(4), object(2)
# memory usage: 45.0+ MB

# %%
df_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540618 entries, 0 to 540617
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   INCIDENT_DATETIME             540618 non-null  datetime64[ns]
#  1   INCIDENT_RESPONSE_SECONDS_QY  528716 non-null  float64
#  2   FIRST_TO_HOSP_DATETIME        377596 non-null  datetime64[ns]
#  3   FIRST_HOSP_ARRIVAL_DATETIME   375786 non-null  datetime64[ns]
#  4   HELD_INDICATOR                540618 non-null  object
#  5   HOSPITAL_TRAVEL               375786 non-null  float64
#  6   ZIPCODE                       534141 non-null  float64
#  7   INCIDENT_DISPOSITION_CODE     539340 non-null  float64
# dtypes: datetime64[ns](3), float64(4), object(1)
# memory usage: 33.0+ MB

# %%
df_ER_info.describe()
# Out:
#        ZIPCODE  INCIDENT_RESPONSE_SECONDS_QY  HOSPITAL_TRAVEL  \
# count  583,489                       576,966          411,321
# mean    10,729                           423              685
# std        543                           228              424
# min     10,000                             0                0
# 25%     10,302                           284              390
# 50%     10,469                           388              600
# 75%     11,224                           519              880
# max     12,345                        14,539            7,418
#
#        INCIDENT_DISPOSITION_CODE
# count                    588,590
# mean                          85
# std                            5
# min                           82
# 25%                           82
# 50%                           82
# 75%                           90
# max                           96

# %%
df_sub.describe()
# Out:
#        INCIDENT_RESPONSE_SECONDS_QY  HOSPITAL_TRAVEL  ZIPCODE  \
# count                       528,716          375,786  534,141
# mean                            424              699   10,740
# std                             229              426      546
# min                               0                0   10,000
# 25%                             284              404   10,303
# 50%                             389              614   10,472
# 75%                             521              900   11,226
# max                          14,539            7,418   12,345
#
#        INCIDENT_DISPOSITION_CODE
# count                    539,340
# mean                          85
# std                            5
# min                           82
# 25%                           82
# 50%                           82
# 75%                           90
# max                           96

# %%
df_ER_info["ER"].fillna(False, inplace=True)

# %%
df_ER_info.query("ZIPCODE==10069")
# Out:
#         ZIPCODE     ER   INCIDENT_DATETIME  INCIDENT_RESPONSE_SECONDS_QY  \
# 5462     10,069  False 2022-03-28 09:40:16                           252
# 6267     10,069  False 2022-03-27 18:28:03                           343
# 12015    10,069  False 2022-03-24 00:03:16                           292
# 15388    10,069  False 2022-03-21 19:42:04                           344
# 26149    10,069  False 2022-03-15 10:10:32                           430
# ...         ...    ...                 ...                           ...
# 568292   10,069  False 2021-04-13 01:22:00                           244
# 574778   10,069  False 2021-04-08 20:34:00                           308
# 575494   10,069  False 2021-04-08 12:45:00                           228
# 582993   10,069  False 2021-04-03 18:54:00                           180
# 587043   10,069  False 2021-04-01 03:16:00                           500
#
#        FIRST_TO_HOSP_DATETIME FIRST_HOSP_ARRIVAL_DATETIME HELD_INDICATOR  \
# ...

# %%
df_ER_true=df_ER_info.query("ER==True")

# %%
df_ER_false=df_ER_info.query("ER==False")

# %%
df_ER_true.describe()
# Out:
#        ZIPCODE  INCIDENT_RESPONSE_SECONDS_QY  HOSPITAL_TRAVEL  \
# count  215,058                       209,707          151,175
# mean    10,687                           408              565
# std        534                           220              402
# min     10,003                             0                0
# 25%     10,037                           272              304
# 50%     10,467                           374              471
# 75%     11,212                           502              713
# max     11,691                        11,294            7,418
#
#        INCIDENT_DISPOSITION_CODE
# count                    214,091
# mean                          85
# std                            5
# min                           82
# 25%                           82
# 50%                           82
# 75%                           90
# max                           96

# %%
df_ER_false.describe()
# Out:
#        ZIPCODE  INCIDENT_RESPONSE_SECONDS_QY  HOSPITAL_TRAVEL  \
# count  368,431                       367,259          260,146
# mean    10,754                           432              755
# std        547                           232              420
# min     10,000                             0                0
# 25%     10,304                           291              467
# 50%     10,473                           396              676
# 75%     11,232                           529              956
# max     12,345                        14,539            6,495
#
#        INCIDENT_DISPOSITION_CODE
# count                    374,499
# mean                          85
# std                            5
# min                           82
# 25%                           82
# 50%                           82
# 75%                           90
# max                           96

# %%
sub_zip_gb_mean = df_sub.groupby("ZIPCODE").mean()

# %%
sub_zip_gb_mean.to_csv("ems severe sub by zip3", index = True, encoding = "UTF8")

# %%
df_sub.query("ZIPCODE==10023")
# Out:
#          INCIDENT_DATETIME  INCIDENT_RESPONSE_SECONDS_QY  \
# 6      2022-03-31 20:09:09                           325
# 56     2022-03-31 19:28:02                           308
# 193    2022-03-31 17:36:23                           216
# 211    2022-03-31 17:22:04                           554
# 310    2022-03-31 15:55:46                           343
# ...                    ...                           ...
# 540187 2021-04-01 05:07:00                           529
# 540201 2021-04-01 04:46:00                           303
# 540287 2021-04-01 02:09:00                           104
# 540301 2021-04-01 01:57:00                           381
# 540371 2021-04-01 00:18:00                           260
#
#        FIRST_TO_HOSP_DATETIME FIRST_HOSP_ARRIVAL_DATETIME HELD_INDICATOR  \
# 6         2022-03-31 20:33:01         2022-03-31 20:42:56              N
# 56        2022-03-31 20:00:10         2022-03-31 20:11:55              N
# ...

# %%
df_sub.query("ZIPCODE==10158")
# Out:
#          INCIDENT_DATETIME  INCIDENT_RESPONSE_SECONDS_QY  \
# 72653  2022-02-08 09:16:45                           192
# 80935  2022-02-02 09:47:10                         2,758
# 88795  2022-01-27 12:53:43                           298
# 155078 2021-12-15 22:29:13                           238
# 207494 2021-11-09 17:56:09                           NaN
# 356201 2021-08-02 11:42:21                           256
#
#        FIRST_TO_HOSP_DATETIME FIRST_HOSP_ARRIVAL_DATETIME HELD_INDICATOR  \
# 72653     2022-02-08 09:45:01         2022-02-08 09:58:26              N
# 80935     2022-02-02 10:47:54         2022-02-02 11:08:26              N
# 88795                     NaT                         NaT              N
# 155078    2021-12-15 22:47:13         2021-12-15 22:53:26              N
# 207494    2021-11-09 18:24:57         2021-11-09 18:28:04              N
# 356201    2021-08-02 11:57:40         2021-08-02 12:02:44              N
#
# ...

# %%
df_sub.query("INCIDENT_DISPOSITION_CODE==82")
# Out:
#          INCIDENT_DATETIME  INCIDENT_RESPONSE_SECONDS_QY  \
# 0      2022-03-31 20:18:35                           314
# 1      2022-03-31 20:17:52                           402
# 2      2022-03-31 20:16:29                           172
# 5      2022-03-31 20:10:37                           253
# 6      2022-03-31 20:09:09                           325
# ...                    ...                           ...
# 540610 2021-03-31 20:24:00                           426
# 540611 2021-03-31 20:23:00                           398
# 540614 2021-03-31 20:22:00                           462
# 540615 2021-03-31 20:21:00                           403
# 540617 2021-03-31 20:20:00                           505
#
#        FIRST_TO_HOSP_DATETIME FIRST_HOSP_ARRIVAL_DATETIME HELD_INDICATOR  \
# 0         2022-03-31 20:46:18         2022-03-31 20:58:24              N
# 1         2022-03-31 21:23:45         2022-03-31 21:36:58              N
# ...

# %%
##code 82 transport to hospital is 378,504 incidents vs. 528,716 total lines, /
##or 71% of calls resulted in transport

# %%
## in rock point, only 81/394 calls resulted in transport (20%)
##in total data, 930,794/1,489,121 resulted in transport (62%)
